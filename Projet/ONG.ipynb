# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("openaq_new.csv", sep=";")
data
# Out:
#       Country Code                              City              Location  \
# 0               ES                       Ciudad Real               ES1279A
# 1               ES                              Lugo               ES0016R
# 2               ES                         Barcelona               ES1018A
# 3               ES                         Barcelona               ES1929A
# 4               ES                 Valencia/València               ES2055A
# ...            ...                               ...                   ...
# 41631           US               Visalia-Porterville  Sequoia and Kings Ca
# 41632           US                             IDAHO  Cottonwood E-sampler
# 41633           US  Los Angeles-Long Beach-Santa Ana          LAX-Hastings
# 41634           US                         CA8 - ARB             MMCA82041
# 41635           US     Milwaukee-Waukesha-West Allis     MILWAUKEE SER DNR
#
# ...

# %%
data['Last Updated'] = pd.to_datetime(data['Last Updated'], utc=True).dt.tz_convert(None)
data_f_dates = data.loc[(data['Last Updated'] >= '2021-08-06 00:00:00') & (data['Last Updated'] < '2021-08-07 00:00:00')]
data_f_dates
# Out:
# Empty DataFrame
# Columns: [Country Code, City, Location, Coordinates, Pollutant, Source Name, Unit, Value, Last Updated, Country Label]
# Index: []

# %%
# Out:
# Empty DataFrame
# Columns: [Country Code, City, Location, Coordinates, Pollutant, Source Name, Unit, Value, Last Updated, Country Label]
# Index: []
